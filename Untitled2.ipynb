# %%
import pandas
from collections import Counter

# %%
df = pandas.read_csv('edited500.csv')
df
# Out:
#          PMID  Index                                         Candidates  \
# 0    10552319      3                                 Quebec, QC, Canada
# 1     8934954      2                 Wells, Somerset, UK|Wells, ME, USA
# 2    11591130      7                      Homer, LA, USA|Homer, AK, USA
# 3    23167678      3                                 Basel, Switzerland
# 4     6143329      3                                  Serbia|Montenegro
# 5    15001970     12                                             UK|USA
# 6    26131722      5                          Melbourne, VIC, Australia
# 7    10216372      1                                     Krakow, Poland
# 8    19841337      1                                 San Diego, CA, USA
# 9    21665017     10                                    Shanghai, China
# 10   12347136     16  Armenia|Russia|Latvia|Uzbekistan|Estonia|Lithu...
# 11   26143942      2                     Benin City, Edo State, Nigeria
# ...

# %%
Counter(df['Sub_type'])
# Out:
# Counter({'method name': 17,
#          'people name': 11,
#          'protein name': 4,
#          'correct placename': 196,
#          'animal name': 13,
#          'biological term': 42,
#          'has 1 got n': 7,
#          'reference': 22,
#          'wrong place': 4,
#          'stains name': 1,
#          'study name': 3,
#          'cell name': 3,
#          'chromosome name': 1,
#          'strain name': 6,
#          'enzyme name': 1,
#          'survey name': 1,
#          'orgnization name': 2,
#          'materials name': 1,
#          'author name': 1,
#          'dataset name': 1,
#          'testing method name': 7,
#          'chemical name': 1,
#          'disease name': 21,
#          'questionnaire name': 1,
#          'search method name': 1,
#          'procedure method name': 1,
#          'has n got 1': 8,
#          'people': 1,
#          'reaction name': 1,
#          'unknown': 3,
#          'method': 1,
#          'bacteria name': 1,
# ...
