# %%
import tarfile, os, re
import numpy as np

# %%
tar = tarfile.open("non_comm_use.0-9A-B.txt.tar.gz", "r:gz")

# %%
c1=0
add=list()
content_txt=str()
for member in tar.getmembers():
    print(c1)
    print ('########################')
    f = tar.extractfile(member)
    c1+=1
    
    c2=0

    if f is not None:
        content = f.read()
        content_txt= content.decode("utf-8")
        print (len(content_txt))
        print ('entered this')
    else:
        print ("!!!!!!!!!NONE")
        print (c1)
    add.append(content_txt.split("===="))
    #add.append(content_txt.split("===="))
        #for i in content_txt:
            #c2+=1
            
            #print (c2)
            #print (i)
            #add.append(content_txt.split("====")[3])
        #print(c2)
    
    if c1>2:
        break
    else:
        pass
# Out:
# 0
# ########################
# !!!!!!!!!NONE
# 1
# 1
# ########################
# 3568
# entered this
# 2
# ########################
# 28856
# entered this

# %%
tar.getnames()
# Out:
# ['Breast_Cancer_Res',
#  'Breast_Cancer_Res/Breast_Cancer_Res_2000_Dec_17_2(1)_1.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_2000_Dec_17_2(1)_2-7.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_2000_Dec_17_2(1)_10-12.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_2000_Dec_17_2(1)_8-9.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_2000_Dec_17_2(1)_13-14.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_2000_Dec_17_2(1)_15-21.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_2000_Dec_17_2(1)_22-27.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_2000_Dec_17_2(1)_28-31.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_2000_Dec_17_2(1)_45-49.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_2000_Dec_17_2(1)_32-44.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_2000_Oct_19_2(1)_E001.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_2000_Oct_20_2(1)_E002.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_1999_Oct_27_1(1)_36-40.txt',
#  'Breast_Cancer_Res/Breast_Cancer_Res_1999_Oct_7_1(1)_22-26.txt',
# ...

# %%
add
# Out:
# [[''],
#  ['\n',
#   ' Front\nBreast Cancer ResBCJBreast Cancer Research1465-54111465-542Xbcr1910.1186/bcr19AnnouncementBreast Cancer Research non-peer-review research\t\t  depository   2000 17 12 1999 2 1 1 1 Copyright © 1999 Current Science Ltd\n',
# ...

# %%
a="1,2,3,4"

# %%
a.split(",")
# Out:
# ['1', '2', '3', '4']

# %%
def typetest(s):
    if float(s)==int(s):
        print ("if")
        return int(s)
    else:
        print ("else")
        return float(s)

# %%
type(typetest(1))
# Out:
# if
# int

# %%
float(1)==int(1)
# Out:
# True

# %%
float(1)
# Out:
# 1.0

# %%
int(1)
# Out:
# 1

# %%
typetest(1.7)
# Out:
# else
# 1.7

# %%
d=dict()

# %%
# ?dict

# %%
dict = {'a': [1,2,3], 'b': 2, 'b': '3'};

# %%
for i in dict["a"]:
    i+=5
    print (i)
# Out:
# 6
# 7
# 8

# %%
a=(0,0,0)

# %%
b=tuple(i+1 for i in a)

# %%
c=(a[2]+1

# %%
c
# Out:
# 1

# %%
(1:3,1:3,1:3)
# Out:
#   File "<ipython-input-8-eeb20a600256>", line 1
#     (1:3,1:3,1:3)
#       ^
# SyntaxError: invalid syntax

# %%
a=[[1,2],[2,3]]

# %%
sum(a[0:1][0:1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-00d1c9228451> in <module>()
# ----> 1 sum(a[0:1][0:1])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
a=np.array([[[0,0,0],[1,1,1],[2,2,2]],[[3,3,3],[4,4,4],[5,5,5]],[[6,6,6],[7,7,7],[8,8,8]]])

# %%
sum(a)
# Out:
# array([[ 9,  9,  9],
#        [12, 12, 12],
#        [15, 15, 15]])

# %%
sum(sum(a))
# Out:
# array([36, 36, 36])

# %%
sum(sum(sum(a)))
# Out:
# 108
