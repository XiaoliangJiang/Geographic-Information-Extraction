# %%
import pandas as pd
import numpy as np

# %%
sample = pd.read_excel("random100edited.xlsx")

# %%
sample
# Out:
#         PMID  Index                                         Candidates  \
# 0   10552319      3                                 Quebec, QC, Canada
# 1    8934954      2                 Wells, Somerset, UK|Wells, ME, USA
# 2   11591130      7                      Homer, LA, USA|Homer, AK, USA
# 3   23167678      3                                 Basel, Switzerland
# 4    6143329      3                                  Serbia|Montenegro
# 5   15001970     12                                             UK|USA
# 6   26131722      5                          Melbourne, VIC, Australia
# 7   10216372      1                                     Krakow, Poland
# 8   19841337      1                                 San Diego, CA, USA
# 9   21665017     10                                    Shanghai, China
# 10  12347136     16  Armenia|Russia|Latvia|Uzbekistan|Estonia|Lithu...
# 11  26143942      2                     Benin City, Edo State, Nigeria
# ...

# %%
sample['Place_or_no']=='Y'
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15     True
# 16    False
# 17    False
# 18     True
# 19     True
# 20     True
# 21     True
# 22    False
# 23    False
# 24     True
# 25     True
# 26    False
# 27    False
# 28     True
# 29    False
#       ...
# 70     True
# 71    False
# 72    False
# 73    False
# 74    False
# 75     True
# 76     True
# 77    False
# 78     True
# 79     True
# 80    False
# 81     True
# 82    False
# 83    False
# 84    False
# 85    False
# 86     True
# 87     True
# 88    False
# 89    False
# 90     True
# 91    False
# 92     True
# 93     True
# 94    False
# 95     True
# 96    False
# 97     True
# 98    False
# 99     True
# Name: Place_or_no, Length: 100, dtype: bool
